# %%
# Importing Dependencies
import pandas as pd
import json

# %%
# Files to load
data = 'C:\\Users\Stephen\Desktop\Class Projects\Covid_and_Politics\Data\covid_and_politics_db.csv'
data
# Out:
# 'C:\\Users\\Stephen\\Desktop\\Class Projects\\Covid_and_Politics\\Data\\covid_and_politics_db.csv'

# %%
covid.df = pd.read_csv(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-acd448b561f3> in <module>
# ----> 1 covid.df = pd.read_csv(data)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
# ...

# %%
d = covid.df.to_dict(orient='records')

# %%
with open('data.json', 'w') as outfile:
    json.dump(d, outfile)

# %%
# Out:
# Cap": 27504.0, "IncomePerCapErr": 633.0, "Poverty": 14.7, "ChildPoverty": 20.1, "Professional": 31.9, "Service": 22.7, "Office": 24.5, "Construction": 11.1, "Production": 9.8, "Drive": 75.2, "Carpool": 11.8, "Transit": 0.3, "Walk": 3.1, "OtherTransp": 2.2, "WorkAtHome": 7.3, "MeanCommute": 23.2, "Employed": 83535.0, "PrivateWork": 76.4, "PublicWork": 14.2, "SelfEmployed": 9.3, "FamilyWork": 0.1, "Unemployment": 7.3}, {"county": "Yazoo", "state": "MS", "percentage16_Donald_Trump": 0.462, "percentage16_Hillary_Clinton": 0.528, "total_votes16": 9892, "votes16_Donald_Trump": 4568, "votes16_Hillary_Clinton": 5221, "percentage20_Donald_Trump": 0.485, "percentage20_Joe_Biden": 0.503, "total_votes20": 9012.0, "votes20_Donald_Trump": 4370.0, "votes20_Joe_Biden": 4533.0, "lat": 32.77890365, "long": -90.39656148, "cases": 1277.0, "deaths": 35.0, "TotalPop": 27496.0, "Men": 14846.0, "Women": 12650.0, "Hispanic": 5.6, "White": 35.8, "Black": 56.4, "Native": 0.2, "Asian": 0.4, "Pacific": 0.0, "Vot
# ...
